# %%
def subtract(a,b):

    return a - b

def distance_from_zero(a):
    b = 0
    x = subtract(a, b)
    distance = abs(x)
    return distance
# Out:
# 4

# %%
print(subtract(1, 5))
print(subtract(7, 2))
print(subtract(-2, 3))
