# %%
def multiply(a, b):
    multiply1 = a * b
    return multiply1

print(multiply(6, 7))
print(multiply(10, 10))
print(multiply(2, 5))
# Out:
# 42
# 100
# 10

# %%
def square(a):
    square1 = multiply(a, a)
    return square1

print(square(4))
# Out:
# 16
