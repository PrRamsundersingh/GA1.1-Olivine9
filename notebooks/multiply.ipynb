# %%
def multiply(a, b):
    multiply1 = a * b
    multiply2 = a ** 2 * b ** 2
    return multiply1, multiply2

print(multiply(6, 7))
print(multiply(10, 10))
print(multiply(2, 5))
# Out:
# (42, 1764)
# (100, 10000)
# (10, 100)
